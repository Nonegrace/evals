# %%
import os
os.environ['OPENAI_API_KEY'] = "XXXX"

import os
os.chdir(os.path.dirname(globals()['_dh'][0]))

# %load_ext autoreload
# %autoreload 2

# %%
# Build the prompts using Chat format. We support converting Chat conversations to text for non-Chat models

from typing import List, Union


def create_chat_example(sys_msg: str, user_prompt: str, subject: dict, examples: Union[List[List[str]], None] = None):
    """
    Form few-shot prompts in the recommended format: https://github.com/openai/openai-python/blob/main/chatml.md#few-shot-prompting
    """
    if "{{" in user_prompt:
        user_prompt = user_prompt.replace("{{", "{")
    if "}}" in user_prompt:
        user_prompt = user_prompt.replace("}}", "}")
    messages = [{"role": "system", "content": sys_msg}]
    if examples:
        for example in examples:
            messages.append({"role": "system", "content": example[0], "name": "example_user"})
            messages.append({"role": "system", "content": example[1], "name": "example_assistant"})
    messages.append({"role": "user", "content": user_prompt.format(**subject)})
    return messages

# %%
import os
import yaml
from datasets import load_dataset

def convert_df_to_json_temp(task_name: str, few_shot: bool = False) -> str:
    registry_path = os.path.join(os.getcwd(), "evals/registry")
    dataset_path = "nguha/legalbench"
    dataset_name = dataset_path.split("/")[-1]
    task_directory = os.path.join(registry_path, "data", dataset_name, task_name)
    os.makedirs(task_directory, exist_ok=True)

    dataset = load_dataset(dataset_path, task_name,  num_proc=8)
    df = dataset["test"].to_pandas()

    prompt_path = os.path.join(os.getcwd(), f"prompts/{dataset_name}/tasks/{task_name}/base_prompt.txt")
    with open(prompt_path, "r") as file:
        prompt = file.read()
    system_prompt, user_prompt = prompt.rsplit("\n\n", 1)

    if few_shot:
        df["sample"] = df.apply(lambda x: create_chat_example(sys_msg=system_prompt, user_prompt=user_prompt, subject=x), axis=1)
    # few_shot_path = os.path.join(task_directory, "few_shot.jsonl")
    # dev_df[["sample"]].to_json(few_shot_path, lines=True, orient="records")

    # Create test prompts and ideal completions
    df["input"] = df.apply(lambda x: create_chat_example(sys_msg=system_prompt, user_prompt=user_prompt, subject=x), axis=1)
    df["ideal"] = df["answer"]
    samples_path = os.path.join(task_directory, "samples.jsonl")
    df[["input", "ideal"]].to_json(samples_path, lines=True, orient="records")

    registry_yaml = {}
    eval_id = f"{dataset_name}-{task_name}"
    registry_yaml[eval_id] = {
        "id": f"{eval_id}.test.v1",
        "metrics": ["accuracy"]
    }
    registry_yaml[f"{eval_id}.test.v1"] = {
        "class": "evals.elsuite.basic.includes:Includes",
        "args": {
            "samples_jsonl": samples_path,
        }
    }

    with open(os.path.join(registry_path, "evals", f"{dataset_name}.yaml"), "a") as f:
        yaml.dump(registry_yaml, f)

# %%
convert_df_to_json_temp("canada_tax_court_outcomes")
# Out:
# Setting num_proc from 8 back to 1 for the train split to disable multiprocessing as it only contains one shard.
# Generating train split: 100%|██████████| 6/6 [00:00<00:00, 15.71 examples/s]
# Setting num_proc from 8 back to 1 for the test split to disable multiprocessing as it only contains one shard.
# Generating test split: 100%|██████████| 244/244 [00:00<00:00, 808.06 examples/s]

# %%
# !python -m evals.cli.oaieval gpt-3.5-turbo legalbench-canada_tax_court_outcomes --max_samples 5 --extra_eval_params ignore_case=True --record_path ./logs/legalbench-canada_tax_court_outcomes
# Out:
# usage: oaieval.py [-h] [--extra_eval_params EXTRA_EVAL_PARAMS]
#                   [--completion_args COMPLETION_ARGS]
#                   [--max_samples MAX_SAMPLES] [--cache | --no-cache]
#                   [--visible | --no-visible] [--seed SEED] [--user USER]
#                   [--record_path RECORD_PATH] [--log_to_file LOG_TO_FILE]
#                   [--registry_path REGISTRY_PATH] [--debug | --no-debug]
#                   [--local-run | --no-local-run] [--http-run | --no-http-run]
#                   [--http-run-url HTTP_RUN_URL]
#                   [--http-batch-size HTTP_BATCH_SIZE]
#                   [--http-fail-percent-threshold HTTP_FAIL_PERCENT_THRESHOLD]
#                   [--dry-run | --no-dry-run]
#                   [--dry-run-logging | --no-dry-run-logging]
#                   completion_fn eval
#
# Run evals through the API
#
# positional arguments:
#   completion_fn         One or more CompletionFn URLs, separated by commas
#                         (,). A CompletionFn can either be the name of a model
#                         available in the OpenAI API or a key in the registry
#                         (see evals/registry/completion_fns).
#   eval                  Name of an eval. See registry.
#
# optional arguments:
#   -h, --help            show this help message and exit
#   --extra_eval_params EXTRA_EVAL_PARAMS
#   --completion_args COMPLETION_ARGS
#                         Specify additional parameters to modify the behavior
#                         of the completion_fn during its creation. Parameters
#                         should be passed as a comma-separated list of key-
#                         value pairs (e.g., 'key1=value1,key2=value2'). This
#                         option allows for the dynamic modification of
#                         completion_fn settings, including the ability to
#                         override default arguments where necessary.
#   --max_samples MAX_SAMPLES
#   --cache, --no-cache
#   --visible, --no-visible
#   --seed SEED
#   --user USER
#   --record_path RECORD_PATH
#   --log_to_file LOG_TO_FILE
#                         Log to a file instead of stdout
#   --registry_path REGISTRY_PATH
#                         Path to the registry
#   --debug, --no-debug
#   --local-run, --no-local-run
#                         Enable local mode for running evaluations. In this
#                         mode, the evaluation results are stored locally in a
#                         JSON file. This mode is enabled by default. (default:
#                         True)
#   --http-run, --no-http-run
#                         Enable HTTP mode for running evaluations. In this
#                         mode, the evaluation results are sent to a specified
#                         URL rather than being stored locally or in Snowflake.
#                         This mode should be used in conjunction with the '--
#                         http-run-url' and '--http-batch-size' arguments.
#                         (default: False)
#   --http-run-url HTTP_RUN_URL
#                         URL to send the evaluation results when in HTTP mode.
#                         This option should be used in conjunction with the '--
#                         http-run' flag.
#   --http-batch-size HTTP_BATCH_SIZE
#                         Number of events to send in each HTTP request when in
#                         HTTP mode. Default is 1, i.e., send events
#                         individually. Set to a larger number to send events in
#                         batches. This option should be used in conjunction
#                         with the '--http-run' flag.
#   --http-fail-percent-threshold HTTP_FAIL_PERCENT_THRESHOLD
#                         The acceptable percentage threshold of HTTP requests
#                         that can fail. Default is 5, meaning 5% of total HTTP
#                         requests can fail without causing any issues. If the
#                         failure rate goes beyond this threshold, suitable
#                         action should be taken or the process will be deemed
#                         as failing, but still stored locally.
#   --dry-run, --no-dry-run
#   --dry-run-logging, --no-dry-run-logging

# %%
# !python -m evals.cli.oaieval gpt-4o-mini  legalbench-consumer_contracts_qa
# Out:
# [2024-09-29 18:37:08,717] [registry.py:276] Loading registry from /Users/guanxiaoyao/qa/legal/research/evals/evals/registry/evals
# [2024-09-29 18:37:09,850] [registry.py:276] Loading registry from /Users/guanxiaoyao/.evals/evals
# [2024-09-29 18:37:09,854] [oaieval.py:215] Run started: 240929103709HDK2HJVG
# [2024-09-29 18:37:09,990] [data.py:94] Fetching /Users/guanxiaoyao/qa/legal/research/evals/evals/registry/data/legalbench/consumer_contracts_qa/samples.jsonl
# [2024-09-29 18:37:09,998] [eval.py:36] Evaluating 396 samples
# [2024-09-29 18:37:10,010] [eval.py:144] Running in threaded mode with 10 threads!
#  23%|█████████▌                                | 90/396 [00:09<00:27, 11.02it/s][2024-09-29 18:37:19,931] [record.py:360] Logged 181 rows of events to /tmp/evallogs/240929103709HDK2HJVG_gpt-4o-mini_legalbench-consumer_contracts_qa.jsonl: insert_time=29.885ms
#  47%|███████████████████▏                     | 185/396 [00:19<00:20, 10.12it/s][2024-09-29 18:37:30,028] [record.py:360] Logged 192 rows of events to /tmp/evallogs/240929103709HDK2HJVG_gpt-4o-mini_legalbench-consumer_contracts_qa.jsonl: insert_time=26.417ms
#  68%|████████████████████████████             | 271/396 [00:29<00:28,  4.39it/s][2024-09-29 18:37:40,469] [record.py:360] Logged 182 rows of events to /tmp/evallogs/240929103709HDK2HJVG_gpt-4o-mini_legalbench-consumer_contracts_qa.jsonl: insert_time=23.067ms
#  95%|███████████████████████████████████████  | 377/396 [00:40<00:02,  9.41it/s][2024-09-29 18:37:50,524] [record.py:360] Logged 204 rows of events to /tmp/evallogs/240929103709HDK2HJVG_gpt-4o-mini_legalbench-consumer_contracts_qa.jsonl: insert_time=27.474ms
# 100%|█████████████████████████████████████████| 396/396 [00:42<00:00,  9.35it/s]
# [2024-09-29 18:37:52,495] [oaieval.py:302] Found 396/396 sampling events with usage data
# [{'completion_tokens': 1, 'prompt_tokens': 528, 'total_tokens': 529, 'completion_tokens_details': CompletionTokensDetails(reasoning_tokens=0)}, {'completion_tokens': 1, 'prompt_tokens': 738, 'total_tokens': 739, 'completion_tokens_details': CompletionTokensDetails(reasoning_tokens=0)}, {'completion_tokens': 1, 'prompt_tokens': 529, 'total_tokens': 530, 'completion_tokens_details': CompletionTokensDetails(reasoning_tokens=0)}, {'completion_tokens': 1, 'prompt_tokens': 787, 'total_tokens': 788, 'completion_tokens_details': CompletionTokensDetails(reasoning_tokens=0)}, {'completion_tokens': 1, 'prompt_tokens': 512, 'total_tokens': 513, 'completion_tokens_details': CompletionTokensDetails(reasoning_tokens=0)}, {'completion_tokens': 1, 'prompt_tokens': 254, 'total_tokens': 255, 'completion_tokens_details': CompletionTokensDetails(reasoning_tokens=0)}, {'completion_tokens': 1, 'prompt_tokens': 913, 'total_tokens': 914, 'completion_tokens_details': CompletionTokensDetails(reasoning_tokens=0)}, {'completion_tokens': 1, 'prompt_tokens': 967, 'total_tokens': 968, 'completion_tokens_details': CompletionTokensDetails(reasoning_tokens=0)}, {'completion_tokens': 1, 'prompt_tokens': 930, 'total_tokens': 931, 'completion_tokens_details': CompletionTokensDetails(reasoning_tokens=0)}, {'completion_tokens': 1, 'prompt_tokens': 1582, 'total_tokens': 1583, 'completion_tokens_details': CompletionTokensDetails(reasoning_tokens=0)}, {'completion_tokens': 1, 'prompt_tokens': 918, 'total_tokens': 919, 'completion_tokens_details': CompletionTokensDetails(reasoning_tokens=0)}, {'completion_tokens': 1, 'prompt_tokens': 678, 'total_tokens': 679, 'completion_tokens_details': CompletionTokensDetails(reasoning_tokens=0)}, {'completion_tokens': 1, 'prompt_tokens': 612, 'total_tokens': 613, 'completion_tokens_details': CompletionTokensDetails(reasoning_tokens=0)}, {'completion_tokens': 1, 'prompt_tokens': 248, 'total_tokens': 249, 'completion_tokens_details': CompletionTokensDetails(reasoning_tokens=0)}, {'completion_tokens': 1, 'prompt_tokens': 511, 'total_tokens': 512, 'completion_tokens_details': CompletionTokensDetails(reasoning_tokens=0)}, {'completion_tokens': 1, 'prompt_tokens': 534, 'total_tokens': 535, 'completion_tokens_details': CompletionTokensDetails(reasoning_tokens=0)}, {'completion_tokens': 1, 'prompt_tokens': 730, 'total_tokens': 731, 'completion_tokens_details': CompletionTokensDetails(reasoning_tokens=0)}, {'completion_tokens': 1, 'prompt_tokens': 608, 'total_tokens': 609, 'completion_tokens_details': CompletionTokensDetails(reasoning_tokens=0)}, {'completion_tokens': 1, 'prompt_tokens': 821, 'total_tokens': 822, 'completion_tokens_details': CompletionTokensDetails(reasoning_tokens=0)}, {'completion_tokens': 1, 'prompt_tokens': 957, 'total_tokens': 958, 'completion_tokens_details': CompletionTokensDetails(reasoning_tokens=0)}, {'completion_tokens': 1, 'prompt_tokens': 545, 'total_tokens': 546, 'completion_tokens_details': CompletionTokensDetails(reasoning_tokens=0)}, {'completion_tokens': 1, 'prompt_tokens': 336, 'total_tokens': 337, 'completion_tokens_details': CompletionTokensDetails(reasoning_tokens=0)}, {'completion_tokens': 1, 'prompt_tokens': 332, 'total_tokens': 333, 'completion_tokens_details': CompletionTokensDetails(reasoning_tokens=0)}, {'completion_tokens': 1, 'prompt_tokens': 397, 'total_tokens': 398, 'completion_tokens_details': CompletionTokensDetails(reasoning_tokens=0)}, {'completion_tokens': 1, 'prompt_tokens': 1253, 'total_tokens': 1254, 'completion_tokens_details': CompletionTokensDetails(reasoning_tokens=0)}, {'completion_tokens': 1, 'prompt_tokens': 636, 'total_tokens': 637, 'completion_tokens_details': CompletionTokensDetails(reasoning_tokens=0)}, {'completion_tokens': 1, 'prompt_tokens': 680, 'total_tokens': 681, 'completion_tokens_details': CompletionTokensDetails(reasoning_tokens=0)}, {'completion_tokens': 1, 'prompt_tokens': 406, 'total_tokens': 407, 'completion_tokens_details': CompletionTokensDetails(reasoning_tok ...
# [2024-09-29 18:37:52,505] [oaieval.py:309] Token usage from 396 sampling events:
# completion_tokens: 396
# prompt_tokens: 247,474
# total_tokens: 247,870
# completion_tokens_details: 0
# [2024-09-29 18:37:52,506] [record.py:371] Final report: {'accuracy': 0.952020202020202, 'boostrap_std': 0.010574834986240955, 'usage_completion_tokens': 396, 'usage_prompt_tokens': 247474, 'usage_total_tokens': 247870, 'usage_completion_tokens_details': 0}. Logged to /tmp/evallogs/240929103709HDK2HJVG_gpt-4o-mini_legalbench-consumer_contracts_qa.jsonl
# [2024-09-29 18:37:52,506] [oaieval.py:233] Final report:
# [2024-09-29 18:37:52,506] [oaieval.py:235] accuracy: 0.952020202020202
# [2024-09-29 18:37:52,506] [oaieval.py:235] boostrap_std: 0.010574834986240955
# [2024-09-29 18:37:52,506] [oaieval.py:235] usage_completion_tokens: 396
# [2024-09-29 18:37:52,506] [oaieval.py:235] usage_prompt_tokens: 247474
# [2024-09-29 18:37:52,506] [oaieval.py:235] usage_total_tokens: 247870
# [2024-09-29 18:37:52,506] [oaieval.py:235] usage_completion_tokens_details: 0
# [2024-09-29 18:37:52,512] [record.py:360] Logged 33 rows of events to /tmp/evallogs/240929103709HDK2HJVG_gpt-4o-mini_legalbench-consumer_contracts_qa.jsonl: insert_time=4.629ms

# %%
# !python -m evals.cli.oaieval o1-mini  legalbench-consumer_contracts_qa
# Out:
# [2024-09-29 18:37:56,120] [registry.py:276] Loading registry from /Users/guanxiaoyao/qa/legal/research/evals/evals/registry/evals
# [2024-09-29 18:37:57,453] [registry.py:276] Loading registry from /Users/guanxiaoyao/.evals/evals
# [2024-09-29 18:37:57,457] [oaieval.py:215] Run started: 240929103757P563FIPD
# [2024-09-29 18:37:57,617] [data.py:94] Fetching /Users/guanxiaoyao/qa/legal/research/evals/evals/registry/data/legalbench/consumer_contracts_qa/samples.jsonl
# [2024-09-29 18:37:57,629] [eval.py:36] Evaluating 396 samples
# [2024-09-29 18:37:57,645] [eval.py:144] Running in threaded mode with 10 threads!
#  12%|█████▏                                    | 49/396 [00:18<02:06,  2.74it/s][2024-09-29 18:38:16,372] [record.py:360] Logged 100 rows of events to /tmp/evallogs/240929103757P563FIPD_o1-mini_legalbench-consumer_contracts_qa.jsonl: insert_time=16.414ms
#  25%|██████████▌                               | 99/396 [00:34<01:43,  2.88it/s][2024-09-29 18:38:32,402] [record.py:360] Logged 100 rows of events to /tmp/evallogs/240929103757P563FIPD_o1-mini_legalbench-consumer_contracts_qa.jsonl: insert_time=22.751ms
#  37%|███████████████▎                         | 148/396 [00:51<01:28,  2.81it/s][2024-09-29 18:38:49,673] [record.py:360] Logged 100 rows of events to /tmp/evallogs/240929103757P563FIPD_o1-mini_legalbench-consumer_contracts_qa.jsonl: insert_time=13.542ms
#  50%|████████████████████▍                    | 197/396 [01:08<01:15,  2.65it/s][2024-09-29 18:39:06,547] [record.py:360] Logged 100 rows of events to /tmp/evallogs/240929103757P563FIPD_o1-mini_legalbench-consumer_contracts_qa.jsonl: insert_time=30.461ms
#  63%|█████████████████████████▊               | 249/396 [01:25<00:40,  3.66it/s][2024-09-29 18:39:23,565] [record.py:360] Logged 100 rows of events to /tmp/evallogs/240929103757P563FIPD_o1-mini_legalbench-consumer_contracts_qa.jsonl: insert_time=13.395ms
#  76%|██████████████████████████████▉          | 299/396 [01:42<00:34,  2.77it/s][2024-09-29 18:39:40,552] [record.py:360] Logged 100 rows of events to /tmp/evallogs/240929103757P563FIPD_o1-mini_legalbench-consumer_contracts_qa.jsonl: insert_time=16.531ms
#  88%|████████████████████████████████████     | 348/396 [01:59<00:15,  3.17it/s][2024-09-29 18:39:57,537] [record.py:360] Logged 100 rows of events to /tmp/evallogs/240929103757P563FIPD_o1-mini_legalbench-consumer_contracts_qa.jsonl: insert_time=14.498ms
# 100%|█████████████████████████████████████████| 396/396 [02:16<00:00,  2.90it/s]
# [2024-09-29 18:40:14,282] [oaieval.py:302] Found 396/396 sampling events with usage data
# [{'completion_tokens': 205, 'prompt_tokens': 822, 'total_tokens': 1027, 'completion_tokens_details': CompletionTokensDetails(reasoning_tokens=192)}, {'completion_tokens': 75, 'prompt_tokens': 524, 'total_tokens': 599, 'completion_tokens_details': CompletionTokensDetails(reasoning_tokens=64)}, {'completion_tokens': 267, 'prompt_tokens': 951, 'total_tokens': 1218, 'completion_tokens_details': CompletionTokensDetails(reasoning_tokens=256)}, {'completion_tokens': 205, 'prompt_tokens': 541, 'total_tokens': 746, 'completion_tokens_details': CompletionTokensDetails(reasoning_tokens=192)}, {'completion_tokens': 267, 'prompt_tokens': 554, 'total_tokens': 821, 'completion_tokens_details': CompletionTokensDetails(reasoning_tokens=256)}, {'completion_tokens': 333, 'prompt_tokens': 264, 'total_tokens': 597, 'completion_tokens_details': CompletionTokensDetails(reasoning_tokens=320)}, {'completion_tokens': 267, 'prompt_tokens': 996, 'total_tokens': 1263, 'completion_tokens_details': CompletionTokensDetails(reasoning_tokens=256)}, {'completion_tokens': 267, 'prompt_tokens': 763, 'total_tokens': 1030, 'completion_tokens_details': CompletionTokensDetails(reasoning_tokens=256)}, {'completion_tokens': 203, 'prompt_tokens': 1623, 'total_tokens': 1826, 'completion_tokens_details': CompletionTokensDetails(reasoning_tokens=192)}, {'completion_tokens': 653, 'prompt_tokens': 938, 'total_tokens': 1591, 'completion_tokens_details': CompletionTokensDetails(reasoning_tokens=640)}, {'completion_tokens': 203, 'prompt_tokens': 630, 'total_tokens': 833, 'completion_tokens_details': CompletionTokensDetails(reasoning_tokens=192)}, {'completion_tokens': 267, 'prompt_tokens': 702, 'total_tokens': 969, 'completion_tokens_details': CompletionTokensDetails(reasoning_tokens=256)}, {'completion_tokens': 203, 'prompt_tokens': 940, 'total_tokens': 1143, 'completion_tokens_details': CompletionTokensDetails(reasoning_tokens=192)}, {'completion_tokens': 461, 'prompt_tokens': 634, 'total_tokens': 1095, 'completion_tokens_details': CompletionTokensDetails(reasoning_tokens=448)}, {'completion_tokens': 333, 'prompt_tokens': 560, 'total_tokens': 893, 'completion_tokens_details': CompletionTokensDetails(reasoning_tokens=320)}, {'completion_tokens': 333, 'prompt_tokens': 256, 'total_tokens': 589, 'completion_tokens_details': CompletionTokensDetails(reasoning_tokens=320)}, {'completion_tokens': 203, 'prompt_tokens': 753, 'total_tokens': 956, 'completion_tokens_details': CompletionTokensDetails(reasoning_tokens=192)}, {'completion_tokens': 203, 'prompt_tokens': 835, 'total_tokens': 1038, 'completion_tokens_details': CompletionTokensDetails(reasoning_tokens=192)}, {'completion_tokens': 461, 'prompt_tokens': 525, 'total_tokens': 986, 'completion_tokens_details': CompletionTokensDetails(reasoning_tokens=448)}, {'completion_tokens': 139, 'prompt_tokens': 654, 'total_tokens': 793, 'completion_tokens_details': CompletionTokensDetails(reasoning_tokens=128)}, {'completion_tokens': 205, 'prompt_tokens': 1279, 'total_tokens': 1484, 'completion_tokens_details': CompletionTokensDetails(reasoning_tokens=192)}, {'completion_tokens': 203, 'prompt_tokens': 559, 'total_tokens': 762, 'completion_tokens_details': CompletionTokensDetails(reasoning_tokens=192)}, {'completion_tokens': 524, 'prompt_tokens': 991, 'total_tokens': 1515, 'completion_tokens_details': CompletionTokensDetails(reasoning_tokens=512)}, {'completion_tokens': 397, 'prompt_tokens': 698, 'total_tokens': 1095, 'completion_tokens_details': CompletionTokensDetails(reasoning_tokens=384)}, {'completion_tokens': 459, 'prompt_tokens': 407, 'total_tokens': 866, 'completion_tokens_details': CompletionTokensDetails(reasoning_tokens=448)}, {'completion_tokens': 269, 'prompt_tokens': 344, 'total_tokens': 613, 'completion_tokens_details': CompletionTokensDetails(reasoning_tokens=256)}, {'completion_tokens': 269, 'prompt_tokens': 458, 'total_tokens': 727, 'completion_tokens_details': CompletionTokensDetails(reasoning_tokens=256)}, {'completion_token ...
# [2024-09-29 18:40:14,291] [oaieval.py:309] Token usage from 396 sampling events:
# completion_tokens: 127,679
# prompt_tokens: 256,016
# total_tokens: 383,695
# completion_tokens_details: 0
# [2024-09-29 18:40:14,292] [record.py:371] Final report: {'accuracy': 0.9419191919191919, 'boostrap_std': 0.011959185385731628, 'usage_completion_tokens': 127679, 'usage_prompt_tokens': 256016, 'usage_total_tokens': 383695, 'usage_completion_tokens_details': 0}. Logged to /tmp/evallogs/240929103757P563FIPD_o1-mini_legalbench-consumer_contracts_qa.jsonl
# [2024-09-29 18:40:14,292] [oaieval.py:233] Final report:
# [2024-09-29 18:40:14,292] [oaieval.py:235] accuracy: 0.9419191919191919
# [2024-09-29 18:40:14,292] [oaieval.py:235] boostrap_std: 0.011959185385731628
# [2024-09-29 18:40:14,292] [oaieval.py:235] usage_completion_tokens: 127679
# [2024-09-29 18:40:14,292] [oaieval.py:235] usage_prompt_tokens: 256016
# [2024-09-29 18:40:14,292] [oaieval.py:235] usage_total_tokens: 383695
# [2024-09-29 18:40:14,292] [oaieval.py:235] usage_completion_tokens_details: 0
# [2024-09-29 18:40:14,304] [record.py:360] Logged 92 rows of events to /tmp/evallogs/240929103757P563FIPD_o1-mini_legalbench-consumer_contracts_qa.jsonl: insert_time=11.000ms

# %%
# !python -m evals.cli.oaieval o1-preview  legalbench-consumer_contracts_qa
# Out:
# [2024-09-29 18:40:17,121] [registry.py:276] Loading registry from /Users/guanxiaoyao/qa/legal/research/evals/evals/registry/evals
# [2024-09-29 18:40:17,985] [registry.py:276] Loading registry from /Users/guanxiaoyao/.evals/evals
# [2024-09-29 18:40:17,986] [oaieval.py:215] Run started: 240929104017NSNMDUP2
# [2024-09-29 18:40:18,081] [data.py:94] Fetching /Users/guanxiaoyao/qa/legal/research/evals/evals/registry/data/legalbench/consumer_contracts_qa/samples.jsonl
# [2024-09-29 18:40:18,088] [eval.py:36] Evaluating 396 samples
# [2024-09-29 18:40:18,097] [eval.py:144] Running in threaded mode with 10 threads!
#  12%|█████▏                                    | 49/396 [00:31<03:13,  1.80it/s][2024-09-29 18:40:51,904] [record.py:360] Logged 100 rows of events to /tmp/evallogs/240929104017NSNMDUP2_o1-preview_legalbench-consumer_contracts_qa.jsonl: insert_time=16.233ms
#  25%|██████████▍                               | 98/396 [01:03<03:42,  1.34it/s][2024-09-29 18:41:22,245] [record.py:360] Logged 100 rows of events to /tmp/evallogs/240929104017NSNMDUP2_o1-preview_legalbench-consumer_contracts_qa.jsonl: insert_time=14.481ms
#  38%|███████████████▍                         | 149/396 [01:33<01:40,  2.45it/s][2024-09-29 18:41:53,081] [record.py:360] Logged 100 rows of events to /tmp/evallogs/240929104017NSNMDUP2_o1-preview_legalbench-consumer_contracts_qa.jsonl: insert_time=14.010ms
#  50%|████████████████████▌                    | 199/396 [02:05<02:54,  1.13it/s][2024-09-29 18:42:24,562] [record.py:360] Logged 100 rows of events to /tmp/evallogs/240929104017NSNMDUP2_o1-preview_legalbench-consumer_contracts_qa.jsonl: insert_time=13.990ms
#  63%|█████████████████████████▊               | 249/396 [02:38<01:09,  2.12it/s][2024-09-29 18:42:57,246] [record.py:360] Logged 100 rows of events to /tmp/evallogs/240929104017NSNMDUP2_o1-preview_legalbench-consumer_contracts_qa.jsonl: insert_time=14.918ms
#  76%|██████████████████████████████▉          | 299/396 [03:10<00:46,  2.10it/s][2024-09-29 18:43:28,534] [record.py:360] Logged 100 rows of events to /tmp/evallogs/240929104017NSNMDUP2_o1-preview_legalbench-consumer_contracts_qa.jsonl: insert_time=10.021ms
#  88%|████████████████████████████████████▏    | 349/396 [03:42<00:32,  1.44it/s][2024-09-29 18:44:01,065] [record.py:360] Logged 100 rows of events to /tmp/evallogs/240929104017NSNMDUP2_o1-preview_legalbench-consumer_contracts_qa.jsonl: insert_time=13.591ms
# 100%|█████████████████████████████████████████| 396/396 [04:32<00:00,  1.45it/s]
# [2024-09-29 18:44:50,744] [oaieval.py:302] Found 396/396 sampling events with usage data
# [{'completion_tokens': 203, 'prompt_tokens': 822, 'total_tokens': 1025, 'completion_tokens_details': CompletionTokensDetails(reasoning_tokens=192)}, {'completion_tokens': 267, 'prompt_tokens': 264, 'total_tokens': 531, 'completion_tokens_details': CompletionTokensDetails(reasoning_tokens=256)}, {'completion_tokens': 267, 'prompt_tokens': 1623, 'total_tokens': 1890, 'completion_tokens_details': CompletionTokensDetails(reasoning_tokens=256)}, {'completion_tokens': 203, 'prompt_tokens': 951, 'total_tokens': 1154, 'completion_tokens_details': CompletionTokensDetails(reasoning_tokens=192)}, {'completion_tokens': 395, 'prompt_tokens': 554, 'total_tokens': 949, 'completion_tokens_details': CompletionTokensDetails(reasoning_tokens=384)}, {'completion_tokens': 331, 'prompt_tokens': 763, 'total_tokens': 1094, 'completion_tokens_details': CompletionTokensDetails(reasoning_tokens=320)}, {'completion_tokens': 715, 'prompt_tokens': 524, 'total_tokens': 1239, 'completion_tokens_details': CompletionTokensDetails(reasoning_tokens=704)}, {'completion_tokens': 395, 'prompt_tokens': 702, 'total_tokens': 1097, 'completion_tokens_details': CompletionTokensDetails(reasoning_tokens=384)}, {'completion_tokens': 203, 'prompt_tokens': 940, 'total_tokens': 1143, 'completion_tokens_details': CompletionTokensDetails(reasoning_tokens=192)}, {'completion_tokens': 651, 'prompt_tokens': 525, 'total_tokens': 1176, 'completion_tokens_details': CompletionTokensDetails(reasoning_tokens=640)}, {'completion_tokens': 1227, 'prompt_tokens': 541, 'total_tokens': 1768, 'completion_tokens_details': CompletionTokensDetails(reasoning_tokens=1216)}, {'completion_tokens': 203, 'prompt_tokens': 835, 'total_tokens': 1038, 'completion_tokens_details': CompletionTokensDetails(reasoning_tokens=192)}, {'completion_tokens': 203, 'prompt_tokens': 753, 'total_tokens': 956, 'completion_tokens_details': CompletionTokensDetails(reasoning_tokens=192)}, {'completion_tokens': 1265, 'prompt_tokens': 996, 'total_tokens': 2261, 'completion_tokens_details': CompletionTokensDetails(reasoning_tokens=832)}, {'completion_tokens': 587, 'prompt_tokens': 630, 'total_tokens': 1217, 'completion_tokens_details': CompletionTokensDetails(reasoning_tokens=576)}, {'completion_tokens': 1099, 'prompt_tokens': 634, 'total_tokens': 1733, 'completion_tokens_details': CompletionTokensDetails(reasoning_tokens=1088)}, {'completion_tokens': 587, 'prompt_tokens': 256, 'total_tokens': 843, 'completion_tokens_details': CompletionTokensDetails(reasoning_tokens=576)}, {'completion_tokens': 779, 'prompt_tokens': 560, 'total_tokens': 1339, 'completion_tokens_details': CompletionTokensDetails(reasoning_tokens=768)}, {'completion_tokens': 459, 'prompt_tokens': 991, 'total_tokens': 1450, 'completion_tokens_details': CompletionTokensDetails(reasoning_tokens=448)}, {'completion_tokens': 459, 'prompt_tokens': 1279, 'total_tokens': 1738, 'completion_tokens_details': CompletionTokensDetails(reasoning_tokens=448)}, {'completion_tokens': 1291, 'prompt_tokens': 938, 'total_tokens': 2229, 'completion_tokens_details': CompletionTokensDetails(reasoning_tokens=1280)}, {'completion_tokens': 459, 'prompt_tokens': 559, 'total_tokens': 1018, 'completion_tokens_details': CompletionTokensDetails(reasoning_tokens=448)}, {'completion_tokens': 395, 'prompt_tokens': 698, 'total_tokens': 1093, 'completion_tokens_details': CompletionTokensDetails(reasoning_tokens=384)}, {'completion_tokens': 715, 'prompt_tokens': 407, 'total_tokens': 1122, 'completion_tokens_details': CompletionTokensDetails(reasoning_tokens=704)}, {'completion_tokens': 715, 'prompt_tokens': 344, 'total_tokens': 1059, 'completion_tokens_details': CompletionTokensDetails(reasoning_tokens=704)}, {'completion_tokens': 395, 'prompt_tokens': 392, 'total_tokens': 787, 'completion_tokens_details': CompletionTokensDetails(reasoning_tokens=384)}, {'completion_tokens': 395, 'prompt_tokens': 458, 'total_tokens': 853, 'completion_tokens_details': CompletionTokensDetails(reasoning_tokens=384)},  ...
# [2024-09-29 18:44:50,753] [oaieval.py:309] Token usage from 396 sampling events:
# completion_tokens: 222,601
# prompt_tokens: 256,016
# total_tokens: 478,617
# completion_tokens_details: 0
# [2024-09-29 18:44:50,754] [record.py:371] Final report: {'accuracy': 0.9318181818181818, 'boostrap_std': 0.013148593912868479, 'usage_completion_tokens': 222601, 'usage_prompt_tokens': 256016, 'usage_total_tokens': 478617, 'usage_completion_tokens_details': 0}. Logged to /tmp/evallogs/240929104017NSNMDUP2_o1-preview_legalbench-consumer_contracts_qa.jsonl
# [2024-09-29 18:44:50,754] [oaieval.py:233] Final report:
# [2024-09-29 18:44:50,754] [oaieval.py:235] accuracy: 0.9318181818181818
# [2024-09-29 18:44:50,754] [oaieval.py:235] boostrap_std: 0.013148593912868479
# [2024-09-29 18:44:50,754] [oaieval.py:235] usage_completion_tokens: 222601
# [2024-09-29 18:44:50,755] [oaieval.py:235] usage_prompt_tokens: 256016
# [2024-09-29 18:44:50,755] [oaieval.py:235] usage_total_tokens: 478617
# [2024-09-29 18:44:50,755] [oaieval.py:235] usage_completion_tokens_details: 0
# [2024-09-29 18:44:50,767] [record.py:360] Logged 92 rows of events to /tmp/evallogs/240929104017NSNMDUP2_o1-preview_legalbench-consumer_contracts_qa.jsonl: insert_time=11.831ms
